# %% [markdown]
# # Learning Pandas

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

LARGE_FIGSIZE = (12, 8)  # defines size of matplotlib figures

# %%
import pandas as pd

# set_option controls many options
pd.set_option("display.max_rows", 16)   # 20 by default

# %% [markdown]
# Using data from a pandas tutorial

# %%
# %cd /media/sf_estudios/pandas/pandas_tutorial/climate_timeseries
# Out:
# /media/sf_estudios/pandas/pandas_tutorial/climate_timeseries

# %% [markdown]
# ## 01 Reading Files

# %%
# using pd.read_table()

# %% [markdown]
# Data has no header, and is separated by several spaces

# %%
# !head data/temperatures/annual.land_ocean.90S.90N.df_1901-2000mean.dat
# Out:
# 1880   -0.1591
# 1881   -0.0789
# 1882   -0.1313
# 1883   -0.1675
# 1884   -0.2485
# 1885   -0.2042
# 1886   -0.1695
# 1887   -0.2505
# 1888   -0.1605
# 1889   -0.1103

# %%
data = pd.read_table("data/temperatures/annual.land_ocean.90S.90N.df_1901-2000mean.dat", 
                     sep="\s+", names=["year", "mean_temp"])

# %%
data  # has a numeric index
# Out:
#      year  mean_temp
# 0    1880    -0.1591
# 1    1881    -0.0789
# 2    1882    -0.1313
# 3    1883    -0.1675
# 4    1884    -0.2485
# 5    1885    -0.2042
# 6    1886    -0.1695
# 7    1887    -0.2505
# ..    ...        ...
# 123  2003     0.5818
# 124  2004     0.5416
# 125  2005     0.6154
# 126  2006     0.5601
# 127  2007     0.5472
# 128  2008     0.4804
# 129  2009     0.5551
# 130  2010  -999.0000
#
# [131 rows x 2 columns]

# %%
data2 = pd.read_table("data/temperatures/annual.land_ocean.90S.90N.df_1901-2000mean.dat", sep="\s+", 
                      names=["year", "mean temp"], index_col=0)
data2
# Out:
#       mean temp
# year
# 1880    -0.1591
# 1881    -0.0789
# 1882    -0.1313
# 1883    -0.1675
# 1884    -0.2485
# 1885    -0.2042
# 1886    -0.1695
# 1887    -0.2505
# ...         ...
# 2003     0.5818
# 2004     0.5416
# 2005     0.6154
# 2006     0.5601
# 2007     0.5472
# 2008     0.4804
# 2009     0.5551
# 2010  -999.0000
#
# [131 rows x 1 columns]

# %% [markdown]
# ### Convert dates on read

# %%
data2 = pd.read_table("data/temperatures/annual.land_ocean.90S.90N.df_1901-2000mean.dat", sep="\s+", 
                      names=["year", "mean temp"], index_col=0, parse_dates=True)
data2
# Out:
#                      mean temp
# year
# 1880-01-01 00:00:00    -0.1591
# 1881-01-01 00:00:00    -0.0789
# 1882-01-01 00:00:00    -0.1313
# 1883-01-01 00:00:00    -0.1675
# 1884-01-01 00:00:00    -0.2485
# 1885-01-01 00:00:00    -0.2042
# 1886-01-01 00:00:00    -0.1695
# 1887-01-01 00:00:00    -0.2505
# ...                        ...
# 2003-01-01              0.5818
# 2004-01-01              0.5416
# 2005-01-01              0.6154
# 2006-01-01              0.5601
# 2007-01-01              0.5472
# 2008-01-01              0.4804
# 2009-01-01              0.5551
# 2010-01-01           -999.0000
#
# [131 rows x 1 columns]

# %%
type(data2)
type(data2.index)
# Out:
# pandas.tseries.index.DatetimeIndex

# %% [markdown]
# ### Data with text on the top and bottom of the file, that I want to skip.
# ### If I dont use engine="python" , I can't use skip_footer

# %%
giss_temp = pd.read_table("data/temperatures/GLB.Ts+dSST.txt", sep="\s+", skiprows=7,
                          skip_footer=11, engine="python")
giss_temp
# Out:
#      Year  Jan  Feb  Mar  Apr   May   Jun   Jul   Aug   Sep   Oct   Nov   Dec  \
# 0    1880  -34  -27  -22  -30   -16   -24   -19   -12   -20   -19   -16   -21
# 1    1881  -13  -16   -2   -3    -3   -27   -12    -8   -18   -23   -28   -18
# 2    1882    3    4   -2  -24   -20   -32   -27   -11   -11   -25   -25   -37
# 3    1883  -38  -38  -12  -20   -20    -8    -3   -13   -19   -19   -28   -21
# 4    1884  -20  -14  -31  -36   -33   -36   -31   -24   -29   -25   -29   -25
# 5    1885  -57  -29  -19  -36   -35   -40   -28   -24   -17   -14   -14     0
# 6    1886  -37  -43  -34  -23   -21   -30   -13   -21   -12   -22   -29   -18
# 7    1887  -60  -43  -26  -34   -28   -25   -19   -28   -24   -33   -29   -40
# ..    ...  ...  ...  ...  ...   ...   ...   ...   ...   ...   ...   ...   ...
# 135  2009   56   48   49   57    59    62    66    61    64    58    72    58
# 136  2010   66   75   87   82    71    60    56    59    55    65    74    44
# 137  2011   45   44   57   60    47    54    70    69    52    60    50    48
# 138  2012   38   43   52   62    71    59    50    56    68    73    69    46
# 139  2013   62   52   60   48    56    61    53    61    73    61    75    61
# 140  2014   68   44   71   72    79    62    50    74    81    78    64    74
# 141  2015   75   80   84   71  ****  ****  ****  ****  ****  ****  ****  ****
# 142  Year  Jan  Feb  Mar  Apr   May   Jun   Jul   Aug   Sep   Oct   Nov   Dec
#
#       J-D  D-N   DJF   MAM   JJA   SON Year.1
# 0     -22  ***  ****   -23   -18   -18   1880
# 1     -14  -14   -17    -3   -15   -23   1881
# 2     -17  -16    -4   -15   -23   -20   1882
# 3     -20  -21   -38   -18    -8   -22   1883
# 4     -28  -28   -18   -33   -31   -28   1884
# 5     -26  -28   -37   -30   -31   -15   1885
# 6     -25  -24   -26   -26   -21   -21   1886
# 7     -32  -30   -40   -29   -24   -28   1887
# ..    ...  ...   ...   ...   ...   ...    ...
# 135    59   59    52    55    63    65   2009
# 136    66   67    66    80    58    65   2010
# 137    55   55    45    55    64    54   2011
# 138    57   57    43    62    55    70   2012
# 139    60   59    53    55    58    70   2013
# 140    68   67    58    74    62    74   2014
# 141  ****  ***    76  ****  ****  ****   2015
# 142   J-D  D-N   DJF   MAM   JJA   SON   Year
#
# [143 rows x 20 columns]

# %% [markdown]
# ## Read from url

# %%
url = "http://sealevel.colorado.edu/files/2015_rel2/sl_ns_global.txt"
global_sea_level = pd.read_table(url, sep="\s+")
global_sea_level
# Out:
#           year  msl_ib_ns(mm)  #version_2015_rel2
# 0    1992.9595         -5.818                 NaN
# 1    1992.9866         -7.525                 NaN
# 2    1993.0138         -9.215                 NaN
# 3    1993.0409        -11.796                 NaN
# 4    1993.0681        -11.291                 NaN
# 5    1993.0952         -9.569                 NaN
# 6    1993.1223         -3.714                 NaN
# 7    1993.1495         -2.471                 NaN
# ..         ...            ...                 ...
# 772  2014.9494         70.723                 NaN
# 773  2014.9766         70.522                 NaN
# 774  2015.0037         66.662                 NaN
# 775  2015.0309         64.804                 NaN
# 776  2015.0580         62.115                 NaN
# 777  2015.0852         68.589                 NaN
# 778  2015.1123         69.745                 NaN
# 779  2015.1395         75.007                 NaN
#
# [780 rows x 3 columns]

# %%
table_list = pd.read_html("http://www.psmsl.org/data/obtaining/")
table_list
type(table_list[0])
# Out:
# pandas.core.frame.DataFrame

# %%
table_list[0]
# Out:
#                        Station Name    ID    Lat.     Lon.  GLOSS ID    \
# 0                          HELIGMAN   231  60.200   19.300         NaN
# 1                      KOBBAKLINTAR    63  60.033   19.883         NaN
# 2                          LEMSTROM    84  60.100   20.017         NaN
# 3                   FOGLO / DEGERBY   249  60.032   20.385         NaN
# 4                         PAGO PAGO   539 -14.280 -170.690       144.0
# 5                   BAHIA ESPERANZA   988 -63.300  -56.917       185.0
# 6                 ARGENTINE ISLANDS   913 -65.246  -64.257       188.0
# 7                  PUERTO SOBERANIA  1603 -62.483  -59.633       189.0
# 8                   ALMIRANTE BROWN   858 -64.900  -62.867         NaN
# 9           CAPE ROBERTS ANTARCTICA  1763 -77.034  163.191         NaN
# 10                       SCOTT BASE  2029 -77.850  166.769       134.0
# 11                          ROTHERA  1931 -67.571  -68.130       342.0
# 12                        USHUAIA I   874 -54.817  -68.217       181.0
# 13                       USHUAIA II  1271 -54.817  -68.217       181.0
# 14                   PUERTO DESEADO   185 -47.750  -65.917       190.0
# 15               COMODORO RIVADAVIA   181 -45.867  -67.483         NaN
# 16                    PUERTO MADRYN   501 -42.767  -65.033       191.0
# 17                         PIRAMIDE   867 -42.583  -64.283         NaN
# 18                          ROSALES   870 -38.933  -62.067         NaN
# 19                          QUEQUEN   223 -38.583  -58.700         NaN
# 20           MAR DEL PLATA (PUERTO)   857 -38.033  -57.533       192.0
# 21       MAR DEL PLATA (NAVAL BASE)   819 -38.033  -57.517       192.0
# 22                       MAR DE AJO  1542 -36.700  -56.667         NaN
# 23                     RIO SANTIAGO   897 -34.850  -57.900         NaN
# 24                     BUENOS AIRES   157 -34.600  -58.367         NaN
# 25                          PALERMO   832 -34.567  -58.400         NaN
# 26               ISLA MARTIN GARCIA   864 -34.183  -58.250         NaN
# 27                           DARWIN   935 -12.472  130.846        62.0
# 28      MILNER BAY (GROOTE EYLANDT)  1160 -13.860  136.416         NaN
# 29                          KARUMBA   835 -17.500  140.833         NaN
# ...                             ...   ...     ...      ...         ...
# 1437                         BOSTON   235  42.353  -71.053         NaN
# 1438                  SEAVEY ISLAND   288  43.080  -70.742         NaN
# 1439   FORT POINT, NEWCASTLE ISLAND  2291  43.072  -70.712         NaN
# 1440               PORTLAND (MAINE)   183  43.657  -70.247         NaN
# 1441                       ROCKLAND  1279  44.105  -69.102         NaN
# 1442  BAR HARBOR, FRENCHMAN BAY, ME   525  44.392  -68.205         NaN
# 1443                      CUTLER II  1524  44.642  -67.297         NaN
# 1444                         CUTLER  1081  44.650  -67.217         NaN
# 1445                       EASTPORT   332  44.903  -66.982         NaN
# 1446                  MIDWAY ISLAND   523  28.212 -177.360       106.0
# 1447                JOHNSTON ISLAND   598  16.738 -169.530       109.0
# 1448                        COLONIA   433 -34.483  -57.850         NaN
# 1449       MONTEVIDEO (PUNTA LOBOS)   431 -34.900  -56.250       300.0
# 1450                 PUNTA DEL ESTE   434 -34.967  -54.950         NaN
# 1451                      LA PALOMA   764 -34.650  -54.150         NaN
# 1452                    PORT VILA B  1841 -17.755  168.308       348.0
# 1453               PUERTO DE HIERRO   782  10.617  -62.083         NaN
# 1454                         GUIRIA  1053  10.567  -62.283         NaN
# 1455                        VUNGTAU  1495  10.333  107.067         NaN
# 1456                    VUNG TAU II  2268  10.340  107.072         NaN
# 1457                        QUINHON  1449  13.767  109.250        75.0
# 1458                    QUI NHON II  2267  13.775  109.255        75.0
# 1459                         DANANG  1475  16.100  108.217         NaN
# 1460                         HONNGU  1003  18.800  105.767         NaN
# 1461                         HONDAU   841  20.667  106.800         NaN
# 1462               CHARLOTTE AMALIE  1393  18.335  -64.920         NaN
# 1463        LIME TREE BAY, ST CROIX  1447  17.693  -64.753         NaN
# 1464          CHRISTIANSTED HARBOUR  2118  17.750  -64.705         NaN
# 1465                   LAMESHUR BAY  2119  18.317  -64.723         NaN
# 1466                           ADEN    44  12.788   44.974         3.0
#
#      Country          Date  Coastline    Station
# 0          ALA  01/01/1980           60        251
# 1          ALA  01/01/1980           60        261
# 2          ALA  01/01/1980           60        271
# 3          ALA  06/10/2015           60        281
# 4          ASM  08/03/2016          745          1
# 5          ATA  11/05/1999          999          1
# 6          ATA  21/05/2015          999          3
# 7          ATA  30/09/2004          999          5
# 8          ATA  01/01/1980          999         24
# 9          ATA  27/09/2010          999         70
# 10         ATA  23/02/2012          999         80
# 11         ATA  21/05/2015          999        103
# 12         ARG  01/01/1980          860          1
# 13         ARG  12/11/2007          860          2
# 14         ARG  21/10/2015          860         11
# 15         ARG  01/01/1980          860         21
# 16         ARG  25/10/2010          860         31
# 17         ARG  01/01/1980          860         41
# 18         ARG  01/01/1980          860         61
# 19         ARG  05/04/1990          860         81
# 20         ARG  01/01/1980          860         91
# 21         ARG  05/08/2015          860        101
# 22         ARG  02/03/1988          860        124
# 23         ARG  01/01/1980          860        141
# 24         ARG  14/05/1991          860        151
# 25         ARG  05/08/2015          860        161
# 26         ARG  01/01/1980          860        171
# 27         AUS  16/03/2016          680         11
# 28         AUS  16/03/2016          680         15
# 29         AUS  30/06/2016          680         18
# ...        ...         ...          ...        ...
# 1437       USA  08/03/2016          960        171
# 1438       USA  26/10/1990          960        177
# 1439       USA  26/04/2016          960        178
# 1440       USA  08/03/2016          960        181
# 1441       USA  22/06/1990          960        186
# 1442       USA  08/03/2016          960        191
# 1443       USA  23/06/2011          960        196
# 1444       USA  01/01/1980          960        197
# 1445       USA  08/03/2016          960        201
# 1446       UMI  08/03/2016          760          1
# 1447       UMI  26/01/2005          760         11
# 1448       URY  23/05/1996          870          1
# 1449       URY  02/02/2016          870         11
# 1450       URY  23/05/1996          870         21
# 1451       URY  03/12/2012          870         31
# 1452       VUT  16/03/2016          741          2
# 1453       VEN  01/01/1980          900          1
# 1454       VEN  20/04/2001          900          6
# 1455       VNM  17/11/2015          605         21
# 1456       VNM  04/11/2015          605         22
# 1457       VNM  17/11/2015          605         41
# 1458       VNM  04/11/2015          605         42
# 1459       VNM  17/11/2015          605         51
# 1460       VNM  17/11/2015          605         61
# 1461       VNM  17/11/2015          605         81
# 1462       VIR  08/03/2016          939          1
# 1463       VIR  08/03/2016          939         11
# 1464       VIR  09/03/2016          939         15
# 1465       VIR  09/03/2016          939         21
# 1466       YEM  01/02/2016          485          1
#
# [1467 rows x 9 columns]
